# %% [markdown]
# <a href="https://colab.research.google.com/github/lmojica25/pyladies_exercises/blob/main/Python_desde_cero_Ejercicio_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ejercicio 3**

# %% [markdown]
# ![Captura de pantalla 2022-09-02 235218.png](data:image/png;base64,...)

# %%
horas_trabajadas = float(input("Introduzca el número de horas trabajadas: "))
costo_hora = float(input("Introduzca el costo por hora: "))
resultado = horas_trabajadas * costo_hora
print(round (resultado,2))
# Out:
# Introduzca el número de horas trabajadas: 12.3
# Introduzca el costo por hora: 23.3456
# 287.15
