# %% [markdown]
# <a href="https://colab.research.google.com/github/lmojica25/pyladies_exercises/blob/main/Python_desde_cero_Ejercicio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ejercicio 1**

# %% [markdown]
# ![Captura de pantalla 2022-09-02 221720.png](data:image/png;base64,...)

# %%
nombre = input("Por Favor Introduzca su Nombre: ")
print("¡Hola", nombre, end ="!")
# Out:
# Por Favor Introduzca su Nombre: Leydi Carolina
# ¡Hola Leydi Carolina!
