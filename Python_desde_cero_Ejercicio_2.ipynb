# %% [markdown]
# <a href="https://colab.research.google.com/github/lmojica25/pyladies_exercises/blob/main/Python_desde_cero_Ejercicio_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ejercicio 2**

# %% [markdown]
# ![Captura de pantalla 2022-09-02 223827.png](data:image/png;base64,...)

# %%
resultado = ((3+2)/(2.5))**2
print(resultado)
# Out:
# 4.0
